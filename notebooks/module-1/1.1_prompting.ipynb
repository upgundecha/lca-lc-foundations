# %% [markdown]
# ## Basic prompting

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage

agent = create_agent(model="gpt-5-nano")

question = HumanMessage(content="What's the capital of the moon?")

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# There isn’t one. The Moon isn’t a country or government, so it has no capital. It’s a natural satellite with features like the Sea of Tranquility, but no political capital.

# %%
system_prompt = "You are a science fiction writer, create a capital city at the users request."

scifi_agent = create_agent(
    model="gpt-5-nano",
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# In a sci‑fi setting, the Moon’s capital could be Lunaris Prime (also called Lunapolis in some tales). Here’s a quick sense of it:
#
# - Location: Nestled inside Tycho Crater on the near side, rim facing Earth. The crater’s floor hosts vast domed districts, while the rim supports orbital lifts and solar farms.
#
# - Government: The Lunar Commonwealth’s seat, the Assembly Spire, where the Prime Council governs from a high, transparent chamber overlooking the crater floor. Earth liaison is handled from the Orbital Exchange Ring above.
#
# - Cityscape: A mosaic of basalt-tile districts, glass-domed parks, and lattice-like towers of reinforced basalt. Magnetic tram belts weave between the domes, and sunlight is harvested by a field of solar sails on the crater rim.
#
# - Landmarks:
#   - The Crown Spire: a kilometer-tall beacon that marks the heart of Lunaris Prime.
#   - The Beacons Park: a public square filled with reflective panels that map Earth’s sky.
#   - Archivum Crateris: the lunar archive, a subterranean library carved from cooled lava tubes.
#
# - Society and culture: Residents live in hollowed basins and arcologies connected by pressurized walkways. Hydroponic farms and ice-mining districts supply daily needs, while a culture of precision, quiet work, and poetry of the Earthrise prevails.
#
# - Economy and tech: Helium-3 and water ice extraction, advanced life-support domes, and a robust Earth–Moon information economy. Gravity is low, so architecture emphasizes verticality and open, airy spaces.
#
# If you’d like, I can tailor Lunaris Prime to a specific vibe—grimdark frontier city, elegant technocratic capital, or vibrant cosmopolitan hub—and sketch a day-in-the-life or a map snippet.

# %% [markdown]
# ## Few-shot examples

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

User: What is the capital of mars?
Scifi Writer: Marsialis

User: What is the capital of Venus?
Scifi Writer: Venusovia

"""

scifi_agent = create_agent(
    model="gpt-5-nano",
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Lunapolis

# %% [markdown]
# ## Structured prompts

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

Please keep to the below structure.

Name: The name of the capital city

Location: Where it is based

Vibe: 2-3 words to describe its vibe

Economy: Main industries

"""

scifi_agent = create_agent(
    model="gpt-5-nano",
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Name: Selene Prime
# Location: Rim of Shackleton Crater, southern polar region of the Moon
# Vibe: Frosted, futuristic
# Economy: Helium-3 mining; solar-power generation; robotics and AI development; lunar tourism

# %% [markdown]
# ## Structured output

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage
from pydantic import BaseModel

class CapitalInfo(BaseModel):
    name: str
    location: str
    vibe: str
    economy: str

agent = create_agent(
    model='gpt-5-nano',
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
    response_format=CapitalInfo
)

question = HumanMessage(content="What is the capital of The Moon?")

response = agent.invoke(
    {"messages": [question]}
)

response["structured_response"]
# Out:
# CapitalInfo(name='Lunaris Prime', location="Shackleton Crater rim, Moon's South Pole", vibe='A gleaming glass-and-ceramic metropolis bathed in near-perpetual daylight, with floating promenades, hydroponic domes, and a chic, utilitarian frontier culture.', economy='Helium-3 mining and water-ice extraction; in-situ resource utilization for construction and life support; lunar tourism; biotech and microgravity research; 3D-printed habitats and orbital trade hubs.')

# %%
response["structured_response"].name
# Out:
# 'Lunaris Prime'

# %%
capital_info = response["structured_response"]

capital_name = capital_info.name
capital_location = capital_info.location

print(f"{capital_name} is a city located at {capital_location}")
# Out:
# Lunaris Prime is a city located at Shackleton Crater rim, Moon's South Pole
