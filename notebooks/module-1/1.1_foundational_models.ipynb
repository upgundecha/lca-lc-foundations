# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Initialising and invoking a model

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(model="gpt-5-nano")

# %%
response = model.invoke("What's the capital of the Moon?")

response
# Out:
# AIMessage(content='There isn’t one. The Moon has no government or cities, so it has no capital. If you’re asking about a fictional world, tell me which book/game, and I can name the capital from that setting.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 565, 'prompt_tokens': 13, 'total_tokens': 578, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 512, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-EONTUjC8yDp5AvbbSxJjAZdg322GA', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a0a53f-c339-7151-87cd-8822e5ff0a58-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 565, 'total_tokens': 578, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 512}})

# %%
print(response.content)
# Out:
# There isn’t one. The Moon has no government or cities, so it has no capital. If you’re asking about a fictional world, tell me which book/game, and I can name the capital from that setting.

# %%
from pprint import pprint

pprint(response.response_metadata)
# Out:
# {'finish_reason': 'stop',
#  'id': 'chatcmpl-EONTUjC8yDp5AvbbSxJjAZdg322GA',
#  'logprobs': None,
#  'model_name': 'gpt-5-nano-2025-08-07',
#  'model_provider': 'openai',
#  'service_tier': 'default',
#  'system_fingerprint': None,
#  'token_usage': {'completion_tokens': 565,
#                  'completion_tokens_details': {'accepted_prediction_tokens': 0,
#                                                'audio_tokens': 0,
#                                                'reasoning_tokens': 512,
#                                                'rejected_prediction_tokens': 0},
#                  'prompt_tokens': 13,
#                  'prompt_tokens_details': {'audio_tokens': 0,
#                                            'cached_tokens': 0},
#                  'total_tokens': 578}}

# %%
pprint(response.usage_metadata)
# Out:
# {'input_token_details': {'audio': 0, 'cache_read': 0},
#  'input_tokens': 13,
#  'output_token_details': {'audio': 0, 'reasoning': 512},
#  'output_tokens': 565,
#  'total_tokens': 578}

# %% [markdown]
# ## Customising your Model

# %%
model = init_chat_model(
    model="gpt-5-nano",
    # Kwargs passed to the model:
    temperature=1.0
)

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# There isn’t one. The Moon has no government or permanent inhabitants, so it has no capital. (In fiction people sometimes imagine lunar cities, but in reality none exists.)

# %% [markdown]
# ## Model Providers

# %% [markdown]
# https://docs.langchain.com/oss/python/integrations/chat

# %%
from langchain.chat_models import init_chat_model
model = init_chat_model(model="claude-sonnet-4-6")

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# The Moon doesn't have a capital city. It has no permanent human settlements, government, or political organization. As of now, it is uninhabited, though various countries and private organizations have plans for future lunar exploration and potential bases.

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-3.1-flash-lite")

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# [{'type': 'text', 'text': 'The Moon does not have a capital city, a government, or any permanent human settlements, so it has no capital.\n\nUnder the **1967 Outer Space Treaty**, which has been signed by all major spacefaring nations, no nation can claim sovereignty over the Moon or any other celestial body. Therefore, there is no political structure that would designate a capital.', 'extras': {'signature': 'EnEKbwERTTIPbN4zJoSf8Jy7XqAEMx/9CSe7+BsBWUZCO9BYeavfpaAzz7QGKklsq6NiZmcbLiv2zdGGFtCFfWPK5RzO4lP9zXtS7l9ev+y3q0x6BeDOepSh54+J+SOq/GtHheRSwTlQQYE3ErgSWdak/w=='}}]

# %% [markdown]
# ## Initialising and invoking an agent

# %%
from langchain.agents import create_agent

agent = create_agent(model=model)

# %%
agent = create_agent(model="claude-sonnet-4-6")

# %%
agent = create_agent("gpt-5-nano")

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?")]}
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='5f033de7-6d15-4a49-a972-e0447f862f8d'),
#               AIMessage(content='There isn’t one. The Moon isn’t a country or government, so it has no capital. If you’re imagining a sci‑fi future, you could invent a city like “Lunapolis” or “Luna City” as a fictional capital.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 767, 'prompt_tokens': 13, 'total_tokens': 780, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 704, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-EONtktKMHlW3esFbLJuuMKEMkZdoA', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a0a558-9f38-7190-bdc2-f5998f3419a3-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 767, 'total_tokens': 780, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 704}})]}

# %%
print(response['messages'][-1].content)
# Out:
# There isn’t one. The Moon isn’t a country or government, so it has no capital. If you’re imagining a sci‑fi future, you could invent a city like “Lunapolis” or “Luna City” as a fictional capital.

# %%
from langchain.messages import AIMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?"),
    AIMessage(content="The capital of the Moon is Luna City."),
    HumanMessage(content="Interesting, tell me more about Luna City")]}
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='fbfea7ea-8b5b-488a-81a5-4bd5f21cf80f'),
#               AIMessage(content='The capital of the Moon is Luna City.', additional_kwargs={}, response_metadata={}, id='445d44f6-b2ed-4ff2-a417-18da5c49bf90', tool_calls=[], invalid_tool_calls=[]),
#               HumanMessage(content='Interesting, tell me more about Luna City', additional_kwargs={}, response_metadata={}, id='7f068ac7-0714-426a-9f65-59bed2a9dcda'),
#               AIMessage(content='There’s no real capital on the Moon today. Luna City is a fictional concept you can use for world-building, a story setting, or a game. Here’s a detailed, self-contained version you can draw from or adapt.\n\nOverview\n- Luna City is imagined as the administrative, scientific, and cultural capital of a lunar settlement federation (or a large international lunar city-state) that coordinates research, resource use, and governance for nearby colonies.\n- Founded in the mid-22nd century as a jointly funded hub, it serves as the primary gateway between Earth and the Moon’s frontier settlements.\n\nLocation and layout\n- Location: A sunny equatorial to mid-latitude crater rim, chosen for reliable solar access and proximity to in-situ resource opportunities, with planned expansion toward polar ice sites.\n- Core district: The Hub, a weatherproof core of life-support, power, and governance offices surrounded by concentric residential and commercial belts.\n- Districts:\n  - Government Row: City hall, a lunar council chamber, courts, and diplomacy suites.\n  - Research Quarter: Universities, labs, ISRU facilities, and microgravity/biology centers.\n  - Habitat Belts: Modular living suites, schools, clinics, parks, and cultural venues.\n  - Industry and ISRU Park: 3D-printing facilities, oxygen and water processing, mineral processing, and manufacturing.\n  - Culture and Tourism Quarter: Museums, galleries, performance spaces, and Earth-Mrise viewing plazas.\n  - Transit Nexus: Tunnels and surface tram lines connecting districts and the orbital transfer hub.\n\nInfrastructure and technology\n- Habitats: Pressurized, radiation-shielded modules linked by air-filled transit corridors and robotic maintenance tunnels. Many structures use regolith shielding and 3D-printed components.\n- Energy: Local solar farms with battery storage; some districts use small-scale nuclear microreactors or compact fusion research. Power is managed by a smart grid that prioritizes life support and critical services during shadows.\n- Water and air: Water ice mined from shadowed craters and processed into drinking water and oxygen; advanced life-support loops recycle air and water.\n- Transport: Surface rovers and hover-taxis for short hops; an underground transit network reduces dust exposure; a potential future orbital elevator or orbital transfer hub links Luna City with Earth-Moon commerce lanes.\n- Materials: In-situ resource utilization (ISRU) for metals, glass, and ceramics; 3D printing of buildings and replacement parts from regolith.\n- Radiation and safety: Multi-layer shielding, magnetic/active fields in critical zones, and strict dust control to protect equipment and health.\n\nGovernance and society\n- Government: Luna City Authority (LCA) or a similar city-state council, with representation from partner nations and settlements in a lunar federation.\n- Law and order: A dedicated lunar police/marine corps (Lunar Guard) handles surface patrols, while a municipal judiciary handles civil matters under a charter aligned with Earth-based treaties.\n- Citizenship and life: Residents may have long-term residency with special civil rights, plus a strong emphasis on education, health, and community culture.\n- Time and routine: A 24-hour Earth-aligned day for work and schooling, with shift rotations designed to balance radiation exposure, maintenance windows, and Earth communication.\n\nCulture and daily life\n- Culture: A blend of Earth arts and lunar-specific traditions—Earthrise festivals, art in glass and metal inspired by the Moon’s geology, and science fairs highlighting ISRU breakthroughs.\n- Education: A networked system of universities and schools, with early hands-on training in life support systems, robotics, geology, and lunar archaeology.\n- Language: Earth Standard is common, with Lunese (a constructed or creole dialect) used in casual settings and cultural programming.\n- Health and wellbeing: Mental health sup ...

# %% [markdown]
# ## Streaming Output

# %%
for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="Tell me all about Luna City, the capital of the Moon")]},
    stream_mode="messages"
):

    # token is a message chunk with token content
    # metadata contains which node produced the token
    
    if token.content:  # Check if there's actual content
        print(token.content, end="", flush=True)  # Print token
# Out:
# Luna City is a fictional concept, since there is no real capital of the Moon today. If you’re building a story or a game, here’s a comprehensive, self-contained concept for a capital city on the Moon called Luna City. It’s written as a cohesive worldbuilding sketch you can drop into fiction or use as a planning reference.
#
# Overview
# - Name: Luna City
# - Status: Capital city of the Moon, seat of government for a lunar federation or confederation (in fiction, the “Moon Commonwealth” or similar).
# - Location: The lunar south polar region, near Shackleton Crater’s rim, selected for access to water ice, stable sunlight on certain slopes, and relatively easy earthward communication. The city is partly on the crater rim and partly underground in shielded basements and caverns.
#
# Why this location
# - Water ice is believed to exist in permanently shadowed craters near the poles, crucial for life support, fuel, and agriculture.
# - The polar sunlight provides long but predictable daylight cycles on sun-facing slopes, enabling solar power with less storage than near the equator.
# - The geology offers natural shielding from radiation and micrometeoroids, useful for a capital with heavy administrative and research modules.
# - Earth visibility is good for political symbolism and diplomacy, while still giving the Moon a distinct, autonomous governance.
#
# Government and society
# - Political structure: A constitutional lunar federation with a central government housed in Luna City. There is a ceremonial Head of State (the Sun Chancellor) and a functional Head of Government (the City Governor) who oversees day-to-day operations. A Lunar Assembly, elected by districts across the Moon, sets laws, budgets, and science policy.
# - Attorney and judiciary: A lunar court system handles inter-settlement disputes, land rights, and regulatory matters; specialized panels oversee water rights, mineral rights, and environmental stewardship to prevent over-exploitation of fragile environments.
# - Citizenship: Residents can be long-term workers, scientists, and settlers who have contributed to lunar development. Dissent and referendum are possible on key issues like expansion, resource sharing, and environmental protections.
# - Security: A Lunar Guard and a civilian-military liaison corps protect critical infrastructure, enforce space treaties, and coordinate with Earth-based agencies in emergencies.
#
# Districts and city layout
# - The Core Dome District: A central, multi-layered hub where government buildings, the central bank, the Supreme Library, and the Lunar Assembly meet. Many spaces are subterranean or partially underground to shield from radiation and temperature swings.
# - The Sunward Arc: A ring of semi-translucent solar domes and workspaces facing the sun for energy generation, housing research labs, light manufacturing, and high-density housing.
# - The Ice Quarters: A district around water-ice processing facilities, fuel depots, and oxygen production plants. It includes storage vaults and a public market for commodities derived from ice.
# - The Cultural Quarter: Museums, theaters, universities, galleries, and a broadcasting house. Architecture emphasizes glassy facades, lunar basalt, and biophilic design to remind residents of Earth’s living landscape while celebrating lunar solitude.
# - The Shielded Wards: Residential sectors built underground or inside lava tubes with artificial gravity corridors, hydroponic farms, clinics, and schools. These zones maximize shielding from radiation and temperature extremes.
# - The Port and Transit Hub: A major landing zone, lunar elevator access, and transit center that links Aurora Springs (nearby bases and resource sites) to Luna City via mag-lev trains, rover corridors, and vertical transit towers.
#
# Economy and key industries
# - Resource extraction and processing: Water ice, oxygen, and hydrogen produced for life support, fuel, and export. Regolith processing yields metals and minerals for construction and manufacturing.
# - Research and development: A hub for lunar and planetary science, astrophysics, materials science (especially in 3D-printed structural materials and regolith composites), and life-support tech.
# - Energy and infrastructure: Large solar farms, storage, and energy management systems powering the entire city and exporting excess energy to off-world installations.
# - Tourism and culture: Educational tours, zero-G experiences in controlled environments, and curated “Earth-to-Luna” heritage experiences that emphasize the Moon’s history with humanity.
# - Governance and finance: A lunar central bank and regulatory bodies that manage currency, debt, and cross-settlement agreements with Earth and Mars entities. Many transactions use a lunar digital currency optimized for off-world transfer.
#
# Technology and infrastructure
# - Energy: Primary solar generation with battery storage and secondary small nuclear or fissionless reactors as backups. Energy smoothing is achieved through a microgrid that can isolate districts during emergencies.
# - Life support: Closed-loop atmosphere systems with oxygen generation from water electrolysis, CO2 scrubbing, and hydroponic food production. Waste recycling is highly automated.
# - Housing: A mix of subterranean modules and elevated domes. Buildings use regolith shielding and dynamic shading to manage temperature. Some areas use rotating sections to generate artificial gravity in long corridors.
# - Transportation:
#   - In-city transit uses magnetic-levitation rails, vacuum-sealed transit tubes, and autonomous rovers.
#   - Point-to-point travel to nearby bases is via crewed landers or small shuttles.
#   - A lunar elevator or tether system can connect surface hubs to a high-altitude orbital platform for rapid Earth-Moon transit.
# - Construction: 3D-printed basalt and regolith composites for shells, with prefabricated interior modules. Buildings are designed to be modular, easily reconfigured as population needs change.
# - Communications: High-bandwidth links to Earth and lunar satellites; low-latency networks within Luna City for governance and operations; holographic meetings and telepresence as standard practice.
#
# Daily life and culture
# - Living conditions: Communities designed for shared space, with a culture that values cooperation, resilience, and scientific curiosity. Education emphasizes STEM, planetary biology, and environmental ethics.
# - Work-life balance: Four-to-six day work weeks in most sectors; long-term missions or research may require extended commitments. Recreation includes simulated Earth landscapes, lunar gardening, and virtual travel education.
# - Education and research: Universities and research institutes produce graduates who run city services, manage water and energy systems, and lead space science. Public lectures and museum events are common.
# - Arts and language: A blend of Earth languages with a distinctive lunar vernacular. Art highlights the tension between isolation and vast connection to Earth; music and sculpture reflect the Moon’s stark beauty and resilience.
# - Festivals: Commemorations of lunar landings, solar cycles, and the founding of Luna City. Quiet, reflective days in the city’s shielded districts celebrate communal life and scientific achievement.
#
# Science, exploration, and diplomacy
# - Lunar science: The capital hosts major observatories and laboratories for astrophysics, geophysics, planetary science, and life-support engineering. It’s a hub for the international lunar research community.
# - Exploration footprint: Luna City acts as the political and logistical center for missions to nearby craters, polar regions, and cislunar space. It coordinates with Earth agencies, commercial operators, and other lunar settlements.
# - Diplomacy: The city maintains Earth-facing facilities for diplomacy, trade negotiations, and cultural exchanges. It also hosts international lunar summits to address shared governance, resource rights, and environmental stewardship.
#
# Challenges and risks
# - Environmental: Radiation, temperature swings, micrometeoroid impact, and dust management are ongoing engineering and health concerns.
# - Resource management: Sustainable water, oxygen, and energy systems are critical. Over-reliance on a single resource or supply chain could threaten city stability.
# - Social cohesion: As a political center with a diverse population of scientists, engineers, and workers, Luna City must manage competing interests, governance legitimacy, and representation.
# - Earth relations: Political shifts on Earth can impact lunar funding, treaties, and defense arrangements. The city must maintain autonomy while staying cooperative.
#
# What a scene in Luna City might feel like
# - The Council Hall sits beneath a protective dome. Outside, the lights of the polar dawn wash over solar arrays, while inside, holographic displays trace the city’s energy flow and water status in real time. A scientist-testified report flickers onto the big screen as representatives debate a new treaty about ice rights. In the residential wards, families move through the shielded corridors, the soft hum of life-support systems a constant reminder that life on the Moon requires constant cooperation and ingenuity.
#
# If you’d like, I can tailor Luna City to a specific tone (hard sci-fi realism, space opera, noir-ish cyberpunk), adjust the location (near the equator, different pole, or in a crater), or expand any section (political structure, architecture, daily life, a sample backstory, or scene). Tell me your preferred genre, era, and the scale of your project, and I’ll refine Luna City accordingly.
